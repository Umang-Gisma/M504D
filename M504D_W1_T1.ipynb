# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang-Gisma/M504D/blob/main/M504D_W1_T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Escape Sequences in Python

# %%
print("\t\tElectricity Bill\n")
print("--------------------------------------------------")
print("Customer Name:\t\t\tUmang Pipaliya")
print("Account Number:\t\t\t123456789")
print("Billing Period:\t\t\t01/12/2025 - 31/12/2025\n")

print("\t\t--- Usage Details ---\n")
print("Previous Reading:\t\t1500 kWh")
print("Current Reading:\t\t1750 kWh")
print("Units Consumed:\t\t\t250 kWh")
print("Rate Per Unit:\t\t\t$0.15\n")

print("\t\t--- Charges ---\n")
print("Energy Charge:\t\t\t$37.50")
print("Fixed Charge:\t\t\t$10.00")
print("Tax (5%):\t\t\t\t$2.38\n")

print("Total Amount Due:\t\t$49.88")
print("Due Date:\t\t\t15/06/2024")
print("--------------------------------------------------\n")
print("\tThank you for your business!")
# Out:
# 		Electricity Bill
#
# --------------------------------------------------
# Customer Name:			Umang Pipaliya
# Account Number:			123456789
# Billing Period:			01/12/2025 - 31/12/2025
#
# 		--- Usage Details ---
#
# Previous Reading:		1500 kWh
# Current Reading:		1750 kWh
# Units Consumed:			250 kWh
# Rate Per Unit:			$0.15
#
# 		--- Charges ---
#
# Energy Charge:			$37.50
# Fixed Charge:			$10.00
# Tax (5%):				$2.38
#
# Total Amount Due:		$49.88
# Due Date:			15/06/2024
# --------------------------------------------------
#
# 	Thank you for your business!
