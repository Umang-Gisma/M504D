# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang-Gisma/M504D/blob/main/M504D_W1_T2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Identify some data science problems on which I want to work in this course and disucss with the class and get feedback

# %% [markdown]
# * I am interested in working on data science problems that focus on understanding user behavior in mobile apps. I want to study how users interact with apps, such as how long they stay, which features they use, and how often they return. By analyzing this data, we can better understand what users need and how they behave. This topic is important because mobile apps are one of the main ways businesses connect with customers, but a lot of user data is not fully used.
#
# * Another problem I want to work on is building prediction models based on user behavior. For example, predicting when users may stop using an app, how engaged they are, or how much value they bring to the business over time. Using machine learning, businesses can act early instead of reacting after problems happen. I am especially interested in comparing different models and checking which ones work best, both from a technical side and a business side.
#
# * Based on these analyses and predictions, I also want to explore AI-based decision support systems for digital businesses. The goal is to turn data insights into clear actions, such as improving user retention, choosing which features to improve, or increasing revenue. This helps connect data science work directly to real business value and fits well with the digital business focus of the program.
#
# * I would like feedback from the class on whether these ideas are suitable
# for this course. I am especially interested in advice about available datasets, evaluation methods, and how to balance technical work with business relevance. I would also appreciate suggestions on how to narrow these topics so they can be completed as individual course projects while still supporting a larger master’s-level research goal.
